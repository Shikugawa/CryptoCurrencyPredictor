# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

datas = pd.DataFrame(
        data = {
            'real_price': [1,3,4,5,6],
            'predicted_price': [2,4,5,5,6]
        }
    )
print(datas)
datas.plot()
plt.show()
# Out:
#    predicted_price  real_price
# 0                2           1
# 1                4           3
# 2                5           4
# 3                5           5
# 4                6           6
